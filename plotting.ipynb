# %%
from pandas import read_csv, DataFrame
from os import getcwd
from re import sub

# %%
##########################################################################################
def get_cleaned_data():
    
    my_curr_dir = getcwd()
    my_file_dir = my_curr_dir + "\data\questionnaire\main_form_cleaned.csv"
    big_df = read_csv(my_file_dir)
    # num_cols = big_df.shape[1]
    # df = big_df.iloc[:, 17:num_cols]
    # df = df.fillna(1)
    # df.drop(1, axis="index", inplace=True)
    # df.reset_index(drop=True, inplace=True)
    
    print("\n Finished reading raw csv file! \n")
    
    return big_df

# %%
df = get_cleaned_data()
df.groupby(by=['condition']).mean()
# Out:
#  Finished reading raw csv file!
#                 pid  difficulty  tlx_mental  tlx_physical  tlx_hurried  \
# condition
# A          7.111111    4.000000    9.444444     11.777778     7.000000
# B          7.111111    4.000000    8.777778     11.444444     6.444444
# C          7.111111    3.111111    9.333333     11.111111     6.111111
# D          7.111111    3.777778    8.777778     11.555556     6.111111
#
#            tlx_successful  tlx_hard  tlx_insecure   tlx_ave     emb_1  \
# condition
# A                7.777778  9.444444      7.222222  8.777778  3.777778
# B                6.222222  9.222222      4.555556  7.777778  4.111111
# C                5.000000  8.444444      3.777778  7.296296  4.444444
# D                6.333333  8.444444      5.333333  7.759259  4.222222
#
#               emb_2     emb_3     emb_4     emb_5     emb_6   emb_ave  \
# condition
# A          3.555556  4.333333  4.666667  4.777778  4.555556  4.277778
# B          4.000000  4.333333  4.888889  5.444444  4.888889  4.611111
# C          4.555556  5.111111  5.333333  5.777778  5.222222  5.074074
# D          4.444444  5.111111  5.222222  5.111111  4.888889  4.833333
#
#            owner_ave  agency_ave
# condition
# A           3.666667    4.583333
# B           4.055556    4.888889
# C           4.500000    5.361111
# D           4.333333    5.083333
